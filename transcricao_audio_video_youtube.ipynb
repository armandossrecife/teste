# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/teste/blob/main/transcricao_audio_video_youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install youtube-transcript-api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 22.0 MB/s eta 0:00:00
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
ytt_api = YouTubeTranscriptApi()

# %%
# retrieve the available transcripts
transcript_list = ytt_api.list('J_a2r3QJNbU')

# %%
# iterate over all available transcripts
for transcript in transcript_list:

    # the Transcript object provides metadata properties
    print(
        transcript.video_id,
        transcript.language,
        transcript.language_code,
        # whether it has been manually created or generated by YouTube
        transcript.is_generated,
        # whether this transcript can be translated or not
        transcript.is_translatable,
        # a list of languages the transcript can be translated to
        transcript.translation_languages,
    )

    # fetch the actual transcript data
    print(transcript.fetch())
# Out:
# J_a2r3QJNbU Portuguese (auto-generated) pt True True [_TranslationLanguage(language='Abkhazian', language_code='ab'), _TranslationLanguage(language='Afar', language_code='aa'), _TranslationLanguage(language='Afrikaans', language_code='af'), _TranslationLanguage(language='Akan', language_code='ak'), _TranslationLanguage(language='Albanian', language_code='sq'), _TranslationLanguage(language='Amharic', language_code='am'), _TranslationLanguage(language='Arabic', language_code='ar'), _TranslationLanguage(language='Armenian', language_code='hy'), _TranslationLanguage(language='Assamese', language_code='as'), _TranslationLanguage(language='Aymara', language_code='ay'), _TranslationLanguage(language='Azerbaijani', language_code='az'), _TranslationLanguage(language='Bangla', language_code='bn'), _TranslationLanguage(language='Bashkir', language_code='ba'), _TranslationLanguage(language='Basque', language_code='eu'), _TranslationLanguage(language='Belarusian', language_code='be'), _Translati
# ...

# %%
# fetch the actual transcript data
transcript_content = transcript.fetch()
print(transcript_content)
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='Olá pessoal meu nome é Armando Soares', start=1.8, duration=3.6), FetchedTranscriptSnippet(text='Souza', start=4.14, duration=3.36), FetchedTranscriptSnippet(text='o seu professor de vocês da disciplina', start=5.4, duration=3.96), FetchedTranscriptSnippet(text='engenharia de software 2', start=7.5, duration=5.219), FetchedTranscriptSnippet(text='nesse período 2023.1', start=9.36, duration=4.46), FetchedTranscriptSnippet(text='bom', start=12.719, duration=4.14), FetchedTranscriptSnippet(text='um breve resumo do meu histórico da', start=13.82, duration=5.2), FetchedTranscriptSnippet(text='minha experiência profissional', start=16.859, duration=4.981), FetchedTranscriptSnippet(text='informei em computação aqui na USP em', start=19.02, duration=4.4), FetchedTranscriptSnippet(text='2001', start=21.84, duration=4.8), FetchedTranscriptSnippet(text='logo depois eu fui morar um tempo em', start=23.42, duration=6.099), FetchedTranscri
# ...

# %%
for transcript in transcript_list:
    # fetch the actual transcript data
    transcript_data = transcript.fetch()
    # Extract and print the text from each snippet
    for snippet in transcript_data:
        # Access the text attribute using dot notation
        print(snippet.text)
# Out:
# Olá pessoal meu nome é Armando Soares
# Souza
# o seu professor de vocês da disciplina
# engenharia de software 2
# nesse período 2023.1
# bom
# um breve resumo do meu histórico da
# minha experiência profissional
# informei em computação aqui na USP em
# 2001
# logo depois eu fui morar um tempo em
# Maceió ali em Recife e fiz
# especialização em Tecnologia de
# Informação em 2004 na UFPE no período
# morando em Recife 2003 2004
# eles especialização em ti
# fiquei um tempo trabalhando no César
# logo depois fiz mestrado não é em 2008
# a região metropolitana de tela vive
# fazia testes
# aplicações de vida
# logo depois em 2009
# eu fui trabalhar como consultor de
# tecnologia no Beach e Washington DC
# fiquei um ano lá em 2010 eu retornei
# para Recife trabalhei um tempo com maior
# coordenada no limites na empresa agora
# que eu passei
# em 2011 eu voltei para Teresina
# fui gerente projeto do grupo Claudino
# do projeto de Tecnologia da Remanso
# junto com sucesso 2011 em 2012
# ...
