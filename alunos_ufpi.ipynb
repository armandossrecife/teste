# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/teste/blob/main/alunos_ufpi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

alunos_computacao = pd.read_html('https://www.sigaa.ufpi.br/sigaa/public/curso/alunos.jsf?lc=pt_BR&id=74268')
alunos_computacao[0]
# Out:
#                     Matrícula                                   Aluno  \
# 0                 20209009505                ADAIAS ABNER BRITO SILVA
# 1                 20169004867                  ADAILTON SILVA PALHANO
# 2                 20159027410               ALAN EVANGELISTA DE SOUSA
# 3                 20229038498              ALAN NUNES VELOSO NOGUEIRA
# 4                 20189016391                 ALAN VITOR BRITO AMORIM
# ..                        ...                                     ...
# 448               20229037919        YASMINE MARTINS DA COSTA E SILVA
# 449               20229004060       YGOR FRANCISCO DE CARVALHO MORAIS
# 450               20219006374             YTALLO GOMES RIBEIRO MENDES
# 451               20189037130  ZACARIAS DO NASCIMENTO SERIANO JUNNIOR
# 452  452  Studens Disponíveis                452  Studens Disponíveis
#
#                    Unnamed: 2
# 0                         NaN
# 1                         NaN
# 2                         NaN
# ...

# %%
type(df_alunos_computacao)
# Out:
# list

# %%
df_alunos_computacao = alunos_computacao[0][['Matrícula', 'Aluno']]
df_alunos_computacao
# Out:
#                     Matrícula                                   Aluno
# 0                 20209009505                ADAIAS ABNER BRITO SILVA
# 1                 20169004867                  ADAILTON SILVA PALHANO
# 2                 20159027410               ALAN EVANGELISTA DE SOUSA
# 3                 20229038498              ALAN NUNES VELOSO NOGUEIRA
# 4                 20189016391                 ALAN VITOR BRITO AMORIM
# ..                        ...                                     ...
# 448               20229037919        YASMINE MARTINS DA COSTA E SILVA
# 449               20229004060       YGOR FRANCISCO DE CARVALHO MORAIS
# 450               20219006374             YTALLO GOMES RIBEIRO MENDES
# 451               20189037130  ZACARIAS DO NASCIMENTO SERIANO JUNNIOR
# 452  452  Studens Disponíveis                452  Studens Disponíveis
#
# [453 rows x 2 columns]

# %%
df_alunos_computacao
# Out:
#                     Matrícula                                   Aluno
# 0                 20209009505                ADAIAS ABNER BRITO SILVA
# 1                 20169004867                  ADAILTON SILVA PALHANO
# 2                 20159027410               ALAN EVANGELISTA DE SOUSA
# 3                 20229038498              ALAN NUNES VELOSO NOGUEIRA
# 4                 20189016391                 ALAN VITOR BRITO AMORIM
# ..                        ...                                     ...
# 448               20229037919        YASMINE MARTINS DA COSTA E SILVA
# 449               20229004060       YGOR FRANCISCO DE CARVALHO MORAIS
# 450               20219006374             YTALLO GOMES RIBEIRO MENDES
# 451               20189037130  ZACARIAS DO NASCIMENTO SERIANO JUNNIOR
# 452  452  Studens Disponíveis                452  Studens Disponíveis
#
# [453 rows x 2 columns]

# %%
df_alunos_computacao.drop(df_alunos_computacao.tail(1).index,inplace=True) # drop last n rows
# Out:
# <ipython-input-6-f27a2c8bc60f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alunos_computacao.drop(df_alunos_computacao.tail(1).index,inplace=True) # drop last n rows

# %%
df_alunos_computacao
# Out:
#        Matrícula                                   Aluno
# 0    20209009505                ADAIAS ABNER BRITO SILVA
# 1    20169004867                  ADAILTON SILVA PALHANO
# 2    20159027410               ALAN EVANGELISTA DE SOUSA
# 3    20229038498              ALAN NUNES VELOSO NOGUEIRA
# 4    20189016391                 ALAN VITOR BRITO AMORIM
# ..           ...                                     ...
# 447  20219041275             WLADIMIR GADELHA DOS SANTOS
# 448  20229037919        YASMINE MARTINS DA COSTA E SILVA
# 449  20229004060       YGOR FRANCISCO DE CARVALHO MORAIS
# 450  20219006374             YTALLO GOMES RIBEIRO MENDES
# 451  20189037130  ZACARIAS DO NASCIMENTO SERIANO JUNNIOR
#
# [452 rows x 2 columns]

# %%
df_alunos_computacao.to_csv('alunos_computacao_ativos_2023.csv', index=False)
