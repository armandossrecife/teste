# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/teste/blob/main/avaliacao_alunos_myaws2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/armandossrecife/teste/main/2024-06-18T1532_Notas-ACFv2BR-LTI13-77207.csv
# Out:
# --2024-06-18 17:37:03--  https://raw.githubusercontent.com/armandossrecife/teste/main/2024-06-18T1532_Notas-ACFv2BR-LTI13-77207.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13526 (13K) [text/plain]
# Saving to: ‘2024-06-18T1532_Notas-ACFv2BR-LTI13-77207.csv.1’
#
# 2024-06-18T1532_Not 100%[===================>]  13.21K  --.-KB/s    in 0s
#
# 2024-06-18 17:37:03 (78.0 MB/s) - ‘2024-06-18T1532_Notas-ACFv2BR-LTI13-77207.csv.1’ saved [13526/13526]

# %%
df_alunos_myaws2 = pd.read_csv('2024-06-18T1532_Notas-ACFv2BR-LTI13-77207.csv')
df_alunos_myaws2
# Out:
#                 Student         ID  SIS User ID  \
# 0       Points Possible        NaN          NaN
# 1          Abreu, Pedro  2818506.0          NaN
# 2   Almeida, Jhoisnayra  2818496.0          NaN
# 3         Andrade, Joao  2819842.0          NaN
# 4        Antonio Junior  2790384.0          NaN
# 5        Augusto, Isaac  2903163.0          NaN
# 6       Bandeira, Lucas  2819844.0          NaN
# 7         Borges, Italo  2818495.0          NaN
# 8       Brandao, Wesley  2818511.0          NaN
# 9           Brito, Luis  2818499.0          NaN
# 10      Calebe, Neemias  2818505.0          NaN
# 11    Carvalho, Vicente  2819839.0          NaN
# 12     Costa, Landerson  2818498.0          NaN
# 13    Ferreira, Weslley  2818512.0          NaN
# 14         Filipe, João  2750194.0          NaN
# 15       Gabriel, Icaro  2818494.0          NaN
# 16        Gustavo, Luis  2818500.0          NaN
# 17         Hugo, Victor  2818510.0          NaN
# ...

# %%
df_alunos_myaws2.columns
# Out:
# Index(['Student', 'ID', 'SIS User ID', 'SIS Login ID', 'Section',
#        'Módulo 1 Teste de conhecimento (778447)',
#        'Avaliação do curso (778441)',
#        'Módulo 2 Teste de conhecimento (778449)',
#        'Módulo 3 Teste de conhecimento (778450)',
#        'Módulo 4 Teste de conhecimento (778451)',
#        'Módulo 5 Teste de conhecimento (778452)',
#        'Módulo 6 Teste de conhecimento (778453)',
#        'Módulo 7 Teste de conhecimento (778454)',
#        'Módulo 8 Teste de conhecimento (778455)',
#        'Módulo 9 Teste de conhecimento (778456)',
#        'Módulo 10 Teste de conhecimento (778448)',
#        'Laboratório 1 - Introdução ao IAM (778442)',
#        'Laboratório 2 - Crie sua VPC e execute um servidor web (778443)',
#        'Laboratório 3 - Introdução ao Amazon EC2 (778444)',
#        'Atividade: AWS Lambda (778440)',
#        'Atividade: AWS Elastic Beanstalk (778439)',
#        'Laboratório 4 - Trabalhando com EBS (778445)',
# ...

# %%
lista_colunas = ['Student', 'ID', 'SIS User ID', 'SIS Login ID', 'Section',
       'Módulo 1 Teste de conhecimento (778447)',
       'Avaliação do curso (778441)',
       'Módulo 2 Teste de conhecimento (778449)',
       'Módulo 3 Teste de conhecimento (778450)',
       'Módulo 4 Teste de conhecimento (778451)',
       'Módulo 5 Teste de conhecimento (778452)',
       'Módulo 6 Teste de conhecimento (778453)',
       'Módulo 7 Teste de conhecimento (778454)',
       'Módulo 8 Teste de conhecimento (778455)',
       'Módulo 9 Teste de conhecimento (778456)',
       'Módulo 10 Teste de conhecimento (778448)',
       'Laboratório 1 - Introdução ao IAM (778442)',
       'Laboratório 2 - Crie sua VPC e execute um servidor web (778443)',
       'Laboratório 3 - Introdução ao Amazon EC2 (778444)',
       'Atividade: AWS Lambda (778440)',
       'Atividade: AWS Elastic Beanstalk (778439)',
       'Laboratório 4 - Trabalhando com EBS (778445)',
       'Laboratório 5 - Crie um servidor de banco de dados e interaja com o banco de dados usando um aplicativo (778446)',
       ' Laboratório 6 - Ajuste a escala e o balanceamento de carga da arquitetura (778438)',
       'Assignments Current Points', 'Assignments Final Points',
       'Assignments Current Score', 'Assignments Unposted Current Score',
       'Assignments Final Score', 'Assignments Unposted Final Score',
       'Knowledge Checks Current Points', 'Knowledge Checks Final Points',
       'Knowledge Checks Current Score',
       'Knowledge Checks Unposted Current Score',
       'Knowledge Checks Final Score', 'Knowledge Checks Unposted Final Score',
       'Labs Current Points', 'Labs Final Points', 'Labs Current Score',
       'Labs Unposted Current Score', 'Labs Final Score',
       'Labs Unposted Final Score', 'Current Points', 'Final Points',
       'Current Score', 'Unposted Current Score', 'Final Score',
       'Unposted Final Score']

# %%
colunas_uteis = [
       'Student',
       'ID',
       'SIS Login ID',
       'Section',
       'Módulo 1 Teste de conhecimento (778447)',
       'Módulo 2 Teste de conhecimento (778449)',
       'Módulo 3 Teste de conhecimento (778450)',
       'Módulo 4 Teste de conhecimento (778451)',
       'Módulo 5 Teste de conhecimento (778452)',
       'Módulo 6 Teste de conhecimento (778453)',
       'Módulo 7 Teste de conhecimento (778454)',
       'Módulo 8 Teste de conhecimento (778455)',
       'Módulo 9 Teste de conhecimento (778456)',
       'Módulo 10 Teste de conhecimento (778448)',
       'Laboratório 1 - Introdução ao IAM (778442)',
       'Laboratório 2 - Crie sua VPC e execute um servidor web (778443)',
       'Laboratório 3 - Introdução ao Amazon EC2 (778444)',
       'Laboratório 4 - Trabalhando com EBS (778445)',
       'Laboratório 5 - Crie um servidor de banco de dados e interaja com o banco de dados usando um aplicativo (778446)',
       ' Laboratório 6 - Ajuste a escala e o balanceamento de carga da arquitetura (778438)',
       'Atividade: AWS Lambda (778440)',
       'Atividade: AWS Elastic Beanstalk (778439)',
       'Avaliação do curso (778441)',
       'Final Points',
       'Final Score'
       ]

# %%
df_alunos_myaws2_filtrado = df_alunos_myaws2[colunas_uteis]
df_alunos_myaws2_filtrado
# Out:
#                 Student         ID                              SIS Login ID  \
# 0       Points Possible        NaN                                       NaN
# 1          Abreu, Pedro  2818506.0                     pedroffda@ufpi.edu.br
# 2   Almeida, Jhoisnayra  2818496.0                         jvrda@ufpi.edu.br
# 3         Andrade, Joao  2819842.0                         judeu@ufpi.edu.br
# 4        Antonio Junior  2790384.0                  acorreiacruz@ufpi.edu.br
# 5        Augusto, Isaac  2903163.0                 isaac.augusto@ufpi.edu.br
# 6       Bandeira, Lucas  2819844.0                   lucasbanmir@ufpi.edu.br
# 7         Borges, Italo  2818495.0                   italoborges@ufpi.edu.br
# 8       Brandao, Wesley  2818511.0              wesleyvitor37417@ufpi.edu.br
# 9           Brito, Luis  2818499.0                 luisfelipe114@ufpi.edu.br
# 10      Calebe, Neemias  2818505.0                 miaskaleb3011@ufpi.edu.br
# ...

# %%
df_alunos_myaws2_filtrado.dropna(inplace=True)
df_alunos_myaws2_filtrado
# Out:
# <ipython-input-23-89d27fc76e00>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alunos_myaws2_filtrado.dropna(inplace=True)
#               Student         ID                 SIS Login ID  \
# 3       Andrade, Joao  2819842.0            judeu@ufpi.edu.br
# 10    Calebe, Neemias  2818505.0    miaskaleb3011@ufpi.edu.br
# 30  Santos, Guilherme  2819840.0  guilhermesantos@ufpi.edu.br
# 33        Sousa, Ryan  2818509.0       ryanfsousa@ufpi.edu.br
#
#                                   Section  \
# 3   AWS Academy Cloud Foundations [77207]
# 10  AWS Academy Cloud Foundations [77207]
# 30  AWS Academy Cloud Foundations [77207]
# 33  AWS Academy Cloud Foundations [77207]
#
#    Módulo 1 Teste de conhecimento (778447)  \
# 3                                    70,00
# ...

# %%
colunas_uteis_alunos_concluidos = ['Student', 'SIS Login ID', 'Section', 'Final Points', 'Final Score']
df_alunos_myaws2_filtrado_alunos_concluidos = df_alunos_myaws2_filtrado[colunas_uteis_alunos_concluidos]
df_alunos_myaws2_filtrado_alunos_concluidos
# Out:
#               Student                 SIS Login ID  \
# 3       Andrade, Joao            judeu@ufpi.edu.br
# 10    Calebe, Neemias    miaskaleb3011@ufpi.edu.br
# 30  Santos, Guilherme  guilhermesantos@ufpi.edu.br
# 33        Sousa, Ryan       ryanfsousa@ufpi.edu.br
#
#                                   Section Final Points Final Score
# 3   AWS Academy Cloud Foundations [77207]      1599,05       84,16
# 10  AWS Academy Cloud Foundations [77207]      1740,00       91,58
# 30  AWS Academy Cloud Foundations [77207]      1637,50       86,18
# 33  AWS Academy Cloud Foundations [77207]      1875,00       98,68

# %%
df_alunos_myaws2_filtrado_alunos_concluidos.sort_values('Final Score', ascending=False)
# Out:
#               Student                 SIS Login ID  \
# 33        Sousa, Ryan       ryanfsousa@ufpi.edu.br
# 10    Calebe, Neemias    miaskaleb3011@ufpi.edu.br
# 30  Santos, Guilherme  guilhermesantos@ufpi.edu.br
# 3       Andrade, Joao            judeu@ufpi.edu.br
#
#                                   Section Final Points Final Score
# 33  AWS Academy Cloud Foundations [77207]      1875,00       98,68
# 10  AWS Academy Cloud Foundations [77207]      1740,00       91,58
# 30  AWS Academy Cloud Foundations [77207]      1637,50       86,18
# 3   AWS Academy Cloud Foundations [77207]      1599,05       84,16
