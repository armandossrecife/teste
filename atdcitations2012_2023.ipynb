# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/teste/blob/main/atdcitations2012_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/armandossrecife/teste/main/atdcitations.csv
# Out:
# --2024-04-30 17:47:12--  https://raw.githubusercontent.com/armandossrecife/teste/main/atdcitations.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27102 (26K) [text/plain]
# Saving to: ‘atdcitations.csv’
#
# atdcitations.csv    100%[===================>]  26.47K  --.-KB/s    in 0.002s
#
# 2024-04-30 17:47:12 (11.7 MB/s) - ‘atdcitations.csv’ saved [27102/27102]

# %%
import pandas as pd

# %%
df_atd_citations = pd.read_csv('atdcitations.csv')
df_atd_citations
# Out:
#                                                Authors  \
# 0    Verdecchia, Roberto; Kruchten, Philippe; Lago,...
# 1                       Martini, Antonio; Bosch, Jan;
# 2       Besker, Terese; Martini, Antonio; Bosch, Jan;
# 3    Nord, Robert L; Ozkaya, Ipek; Kruchten, Philip...
# 4    Verdecchia, Roberto; Malavolta, Ivano; Lago, P...
# ..                                                 ...
# 123                          da S Maldonado, Everton;
# 124  Diaz-Pace, J Andres; Tommasel, Antonela; Pigaz...
# 125                                 Muratdağı, Tolga;
# 126              Kruizinga, Ronald; Scheedler, Ruben;
# 127                                 Güler, Murat Can;
#
#                                                  Title  \
# 0      Architectural technical debt: A grounded theory
# 1    The danger of architectural technical debt: Co...
# 2    Managing architectural technical debt: A unifi...
# 3    In search of a metric for managing architectur...
# ...

# %%
df_atd_citations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Authors      128 non-null    object
#  1   Title        128 non-null    object
#  2   Publication  102 non-null    object
#  3   Volume       34 non-null     float64
#  4   Number       12 non-null     float64
#  5   Pages        88 non-null     object
#  6   Year         124 non-null    float64
#  7   Publisher    90 non-null     object
# dtypes: float64(3), object(5)
# memory usage: 8.1+ KB

# %%
my_columns = ['Title', 'Authors', 'Year', 'Publication']
df_my_data = df_atd_citations[my_columns]

df_my_data_valids = df_my_data.dropna()
df_my_data_valids['Year'] = df_my_data_valids['Year'].astype(int)
df_my_data_valids = df_my_data_valids.sort_values(by='Year')
# Out:
# <ipython-input-10-9164259b1eb0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_my_data_valids['Year'] = df_my_data_valids['Year'].astype(int)

# %%
df_my_data_valids
# Out:
#                                                  Title  \
# 3    In search of a metric for managing architectur...
# 29   An empirical investigation of modularity metri...
# 26              Measuring Architectural Technical Debt
# 112  Architectural debt management in value-oriente...
# 57   Measure it? manage it? ignore it? software pra...
# ..                                                 ...
# 38   Architectural Technical Debt-A Systematic Mapp...
# 88   Design methods for Diagnosing and Locating Ent...
# 55   Software design analysis and technical debt ma...
# 20   Architectural technical debt: an identificatio...
# 64   Quantifying technical debt: A systematic mappi...
#
#                                                Authors  Year  \
# 3    Nord, Robert L; Ozkaya, Ipek; Kruchten, Philip...  2012
# 29   Li, Zengyang; Liang, Peng; Avgeriou, Paris; Gu...  2014
# 26   Kuznetcov, Michail; NV, ABN AMRO Bank; Mahlerl...  2014
# ...

# %%
df_my_data_valids.to_csv('atdcitations2012-2023.csv', index=False)

# %%
# !wget https://github.com/armandossrecife/teste/raw/main/atdcitations2012-2023.xlsx
# Out:
# --2024-04-30 18:40:11--  https://github.com/armandossrecife/teste/raw/main/atdcitations2012-2023.xlsx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/armandossrecife/teste/main/atdcitations2012-2023.xlsx [following]
# --2024-04-30 18:40:11--  https://raw.githubusercontent.com/armandossrecife/teste/main/atdcitations2012-2023.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29695 (29K) [application/octet-stream]
# Saving to: ‘atdcitations2012-2023.xlsx’
#
# atdcitations2012-20 100%[===================>]  29.00K  --.-KB/s    in 0.002s
#
# ...

# %%
df_my_data_valids_links = pd.read_excel('atdcitations2012-2023.xlsx')
df_my_data_valids_links
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                  Title  \
# 0    In search of a metric for managing architectur...
# 1    An empirical investigation of modularity metri...
# 2               Measuring Architectural Technical Debt
# 3    Architectural debt management in value-oriente...
# 4    Measure it? manage it? ignore it? software pra...
# ..                                                 ...
# 96   Architectural Technical Debt-A Systematic Mapp...
# 97   Design methods for Diagnosing and Locating Ent...
# 98   Software design analysis and technical debt ma...
# 99   Architectural technical debt: an identificatio...
# 100  Quantifying technical debt: A systematic mappi...
#
#                                                   Link  \
# 0    https://ieeexplore.ieee.org/abstract/document/...
# ...

# %%
element_counts_by_year = df_my_data_valids_links['Year'].to_list()

# %%
from collections import Counter

element_counts = Counter(element_counts_by_year)

# %%
for k, v in element_counts.items():
  print(k, v)
# Out:
# 2012 1
# 2014 3
# 2015 10
# 2016 7
# 2017 4
# 2018 8
# 2019 8
# 2020 14
# 2021 21
# 2022 11
# 2023 14

# %%
import os

for link in df_my_data_valids_links['Link'].to_list():
  os.environ['MY_LINK'] = link
  # !wget $MY_LINK
# Out:
# --2024-04-30 18:51:35--  https://ieeexplore.ieee.org/abstract/document/6337765
# Resolving ieeexplore.ieee.org (ieeexplore.ieee.org)... 18.65.25.129, 18.65.25.92, 18.65.25.38, ...
# Connecting to ieeexplore.ieee.org (ieeexplore.ieee.org)|18.65.25.129|:443... connected.
# HTTP request sent, awaiting response... 418 Unknown Code
# 2024-04-30 18:51:35 ERROR 418: Unknown Code.
#
# --2024-04-30 18:51:35--  https://dl.acm.org/doi/abs/10.1145/2602576.2602581
# Resolving dl.acm.org (dl.acm.org)... 104.18.42.89, 172.64.145.167
# Connecting to dl.acm.org (dl.acm.org)|104.18.42.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘2602576.2602581’
#
# 2602576.2602581         [    <=>             ] 108.29K  79.7KB/s    in 1.4s
#
# 2024-04-30 18:51:37 (79.7 KB/s) - ‘2602576.2602581’ saved [110885]
#
# --2024-04-30 18:51:37--  https://www.ru.nl/publish/pages/769526/z-mscis-s4340132-mkuznetcov-2014-08-28.pdf
# ...

# %%
import requests

proxy_url = f"http://username:password@your_proxy_host:port"
username = "?"
password = "?"

proxies = {
    "http": proxy_url,
    "https": proxy_url,
}

# Send a request using the proxy
#response = requests.get("https://www.google.com", proxies=proxies)
# Access response data as usual
#print(response.content)

# %%
def login_to_gateway(username, password):
    login_url = "https://200.137.162.119:6082/php/uid.php"
    payload = {
        "vsys": "1",
        "rule": "0",
        "url": "http://conecta.ufpi.br",
        "user": username,
        "passwd": password
    }

# %%
def login_to_gateway2(username, password):
    login_url = "https://200.137.162.119:6082/php/uid.php?vsys=1&rule=0&url=http://conecta.ufpi.br"
    payload = {
        "user": username,
        "passwd": password
    }

    try:
        # Send POST request to login URL
        print('Aguarde...')
        response = requests.post(login_url, data=payload, allow_redirects=False, timeout=15, verify=False)

        # Check if the response is a redirect
        if response.status_code == 302:
            # Get the redirected URL from the Location header
            redirected_url = response.headers.get('Location')
            print("Login successful. Redirected to:", redirected_url)
        else:
            print("Login failed with status code:", response.status_code)
    except requests.exceptions.RequestException as e:
        print("Error:", e)

# Replace 'your_username' and 'your_password' with your actual credentials
login_to_gateway2("?", "?")
# Out:
# Aguarde...
# Error: HTTPSConnectionPool(host='200.137.162.119', port=6082): Max retries exceeded with url: /php/uid.php?vsys=1&rule=0&url=http://conecta.ufpi.br (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ddf28adb520>, 'Connection to 200.137.162.119 timed out. (connect timeout=15)'))
