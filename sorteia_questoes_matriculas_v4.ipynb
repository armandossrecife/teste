# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/teste/blob/main/sorteia_questoes_matriculas_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sorteio de questões

# %%
import random

# Listas de exercícios
lista_exercicios = ['1a', '2a', '3a', '4a', '5a', '6a', '7a', '8a', '9a', '1b', '2b', '3b', '1c', '1d']

# Lista de matrículas
lista_matriculas = ['20249023385','20249021433','20249012229','20249021818','20239035515','20249022000','20249018456',
'20249021264','20249020884','20249022010','20229052844','20249013226','20249011704','20239057110','20249023278',
'20249021961','20249012194','20249021970','20249020857','20249012050','20249011769','20249021139','20239049987',
'20239052276','20249012336','20219042129','20249021765','20249011553','20239046116','20249021999','20249023170']

def sortear_questao_e_matricula(lista_exercicios, lista_matriculas):
  """Sorteia aleatoriamente uma questão e uma matrícula.

  Returns:
    Uma tupla contendo a questão sorteada e a matrícula sorteada.
  """
  if not lista_exercicios or not lista_matriculas:
    return None, None

  lista_questoes_ja_sorteadas = []
  lista_matriculas_ja_sorteadas = []

  for _ in range(len(lista_exercicios)):
    questao_sorteada = random.choice(lista_exercicios)
    while questao_sorteada in lista_questoes_ja_sorteadas:
      questao_sorteada = random.choice(lista_exercicios)

    lista_questoes_ja_sorteadas.append(questao_sorteada)

  for _ in range(len(lista_exercicios)):
    matricula_sorteada = random.choice(lista_matriculas)
    while matricula_sorteada in lista_matriculas_ja_sorteadas:
      matricula_sorteada = random.choice(lista_matriculas)

    lista_matriculas_ja_sorteadas.append(matricula_sorteada)

  return lista_questoes_ja_sorteadas, lista_matriculas_ja_sorteadas

# %%
lista_questoes_ja_sorteadas, lista_matriculas_ja_sorteadas = sortear_questao_e_matricula(lista_exercicios, lista_matriculas)

print(f"Lista de {len(lista_questoes_ja_sorteadas)} questões sorteadas: {lista_questoes_ja_sorteadas}")
print(f"Lista de {len(lista_matriculas_ja_sorteadas)} matrículas sorteadas: {lista_matriculas_ja_sorteadas}")
# Out:
# Lista de 14 questões sorteadas: ['5a', '1a', '1b', '1c', '7a', '8a', '6a', '3a', '4a', '2b', '9a', '3b', '1d', '2a']
# Lista de 14 matrículas sorteadas: ['20249021765', '20219042129', '20249021818', '20239046116', '20249022010', '20249011704', '20239035515', '20249021139', '20249012194', '20249011553', '20249013226', '20229052844', '20239057110', '20249012050']

# %%
lista_questoes_ja_sorteadas.sort()

for questao, matricula in zip(lista_questoes_ja_sorteadas, lista_matriculas_ja_sorteadas):
  print(f"Questão: {questao}, Matrícula: {matricula}")
# Out:
# Questão: 1a, Matrícula: 20249021765
# Questão: 1b, Matrícula: 20219042129
# Questão: 1c, Matrícula: 20249021818
# Questão: 1d, Matrícula: 20239046116
# Questão: 2a, Matrícula: 20249022010
# Questão: 2b, Matrícula: 20249011704
# Questão: 3a, Matrícula: 20239035515
# Questão: 3b, Matrícula: 20249021139
# Questão: 4a, Matrícula: 20249012194
# Questão: 5a, Matrícula: 20249011553
# Questão: 6a, Matrícula: 20249013226
# Questão: 7a, Matrícula: 20229052844
# Questão: 8a, Matrícula: 20239057110
# Questão: 9a, Matrícula: 20249012050

# %% [markdown]
# # Lista de alunos matriculados

# %%
# !wget https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lp_20242.csv
# Out:
# --2024-10-22 10:53:21--  https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lp_20242.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1319 (1.3K) [text/plain]
# Saving to: ‘alunos_lp_20242.csv’
#
# alunos_lp_20242.csv 100%[===================>]   1.29K  --.-KB/s    in 0s
#
# 2024-10-22 10:53:21 (22.5 MB/s) - ‘alunos_lp_20242.csv’ saved [1319/1319]

# %%
import pandas as pd

df_alunos_20242 = pd.read_csv('alunos_lp_20242.csv')
df_alunos_20242
# Out:
#       matricula                                        nome
# 0   20249023385  ANTONIO CARLOS DE SOUSA COELHO DAMASCENO\t
# 1   20249021433              ANTONIO INACIO DA SILVA NETO\t
# 2   20249012229            ARTHUR MAGNO RODRIGUES SAMPAIO\t
# 3   20249021818                     CAUA MARTINS DA SILVA\t
# 4   20239035515                     DAVI SOARES DE MACEDO\t
# 5   20249022000                         DAVI SOUSA SOARES\t
# 6   20249018456            DIEGO VINICIOS MASCARENHA LIMA\t
# 7   20249021264                DIELSON DE MENDONCA SANTOS\t
# 8   20249020884           FELIPE GABRIEL SOARES RODRIGUES\t
# 9   20249022010                      GABRIEL ARAUJO ROCHA\t
# 10  20229052844                       HELON SANDES BARROS\t
# 11  20249013226               ITALO MARLON DE SOUSA ALVES\t
# 12  20249011704            JARDENIA MILLENA DE SOUSA ROSA\t
# 13  20239057110              JOAO GABRIEL MIRANDA QUEIROZ\t
# 14  20249023278                 JOAO MANOEL COSTA MENEZES\t
# 15  20249021961       JOAO MARCELO BARROS CARDOSO VENTURA\t
# 16  20249012194                 JOAO PEDRO SALEH DE SOUSA\t
# 17  20249021970            KAUAN FRANCISCO SANTOS SARAIVA\t
# 18  20249020857          LUANDERSON DAVI GONCALVES TORRES\t
# 19  20249012050           LUANDERSON OLIVEIRA DE CARVALHO\t
# 20  20249011769  LUCAS VILARINHO CARVALHO MARTINS CAMARCO\t
# 21  20249021139              MARCOS VINICIUS DUARTE SOUSA\t
# 22  20239049987                MARIA EDUARDA FARIAS GOMES\t
# 23  20239052276           MATEUS RODRIGUES DE SOUSA BORJA\t
# 24  20249012336                   MATHEUS CARNEIRO AGUIAR\t
# 25  20219042129           NORBERTO MELO DE CARVALHO FILHO\t
# 26  20249021765      RAIMUNDO NONATO DA SILVA SA SOBRINHO\t
# 27  20249011553                   SAMARA FEITOSA DE SOUSA\t
# 28  20239046116               TIAGO GABRIEL COSTA SAMPAIO\t
# 29  20249021999             VICTOR KAUAN DA SILVA MIRANDA\t
# 30  20249023170           WELTER XIMENES CANTANHEDE FILHO\t

# %%
lista_alunos_matriculados = df_alunos_20242.matricula.tolist()
print(f"Lista de {len(lista_alunos_matriculados)} alunos matriculados: {lista_alunos_matriculados}")
# Out:
# Lista de 31 alunos matriculados: [20249023385, 20249021433, 20249012229, 20249021818, 20239035515, 20249022000, 20249018456, 20249021264, 20249020884, 20249022010, 20229052844, 20249013226, 20249011704, 20239057110, 20249023278, 20249021961, 20249012194, 20249021970, 20249020857, 20249012050, 20249011769, 20249021139, 20239049987, 20239052276, 20249012336, 20219042129, 20249021765, 20249011553, 20239046116, 20249021999, 20249023170]

# %%
matricula_sorteada = random.choice(lista_alunos_matriculados)
print(f"Matrícula sorteada: {matricula_sorteada}")
df_alunos_20242.query(f"matricula=={matricula_sorteada}")
# Out:
# Matrícula sorteada: 20249012336
#       matricula                       nome
# 24  20249012336  MATHEUS CARNEIRO AGUIAR\t

# %%
lista_nomes_alunos = df_alunos_20242.nome.tolist()
print(f"Lista de {len(lista_nomes_alunos)} nomes de alunos: {lista_nomes_alunos}")
# Out:
# Lista de 31 nomes de alunos: ['ANTONIO CARLOS DE SOUSA COELHO DAMASCENO\t', 'ANTONIO INACIO DA SILVA NETO\t', 'ARTHUR MAGNO RODRIGUES SAMPAIO\t', 'CAUA MARTINS DA SILVA\t', 'DAVI SOARES DE MACEDO\t', 'DAVI SOUSA SOARES\t', 'DIEGO VINICIOS MASCARENHA LIMA\t', 'DIELSON DE MENDONCA SANTOS\t', 'FELIPE GABRIEL SOARES RODRIGUES\t', 'GABRIEL ARAUJO ROCHA\t', 'HELON SANDES BARROS\t', 'ITALO MARLON DE SOUSA ALVES\t', 'JARDENIA MILLENA DE SOUSA ROSA\t', 'JOAO GABRIEL MIRANDA QUEIROZ\t', 'JOAO MANOEL COSTA MENEZES\t', 'JOAO MARCELO BARROS CARDOSO VENTURA\t', 'JOAO PEDRO SALEH DE SOUSA\t', 'KAUAN FRANCISCO SANTOS SARAIVA\t', 'LUANDERSON DAVI GONCALVES TORRES\t', 'LUANDERSON OLIVEIRA DE CARVALHO\t', 'LUCAS VILARINHO CARVALHO MARTINS CAMARCO\t', 'MARCOS VINICIUS DUARTE SOUSA\t', 'MARIA EDUARDA FARIAS GOMES\t', 'MATEUS RODRIGUES DE SOUSA BORJA\t', 'MATHEUS CARNEIRO AGUIAR\t', 'NORBERTO MELO DE CARVALHO FILHO\t', 'RAIMUNDO NONATO DA SILVA SA SOBRINHO\t', 'SAMARA FEITOSA DE SOUSA\t', 'TIAGO GABRIEL COSTA SAMPAIO\t', 'VICTOR KAUAN DA SILVA MIRANDA\t', 'WELTER XIMENES CANTANHEDE FILHO\t']

# %%
lista_nomes_alunos_limpos = []
for each in lista_nomes_alunos:
  each = each.replace("\t", "")
  lista_nomes_alunos_limpos.append(each)

lista_nomes_alunos_limpos
# Out:
# ['ANTONIO CARLOS DE SOUSA COELHO DAMASCENO',
#  'ANTONIO INACIO DA SILVA NETO',
#  'ARTHUR MAGNO RODRIGUES SAMPAIO',
#  'CAUA MARTINS DA SILVA',
#  'DAVI SOARES DE MACEDO',
#  'DAVI SOUSA SOARES',
#  'DIEGO VINICIOS MASCARENHA LIMA',
#  'DIELSON DE MENDONCA SANTOS',
#  'FELIPE GABRIEL SOARES RODRIGUES',
#  'GABRIEL ARAUJO ROCHA',
#  'HELON SANDES BARROS',
#  'ITALO MARLON DE SOUSA ALVES',
#  'JARDENIA MILLENA DE SOUSA ROSA',
#  'JOAO GABRIEL MIRANDA QUEIROZ',
#  'JOAO MANOEL COSTA MENEZES',
#  'JOAO MARCELO BARROS CARDOSO VENTURA',
#  'JOAO PEDRO SALEH DE SOUSA',
#  'KAUAN FRANCISCO SANTOS SARAIVA',
#  'LUANDERSON DAVI GONCALVES TORRES',
#  'LUANDERSON OLIVEIRA DE CARVALHO',
#  'LUCAS VILARINHO CARVALHO MARTINS CAMARCO',
#  'MARCOS VINICIUS DUARTE SOUSA',
#  'MARIA EDUARDA FARIAS GOMES',
#  'MATEUS RODRIGUES DE SOUSA BORJA',
#  'MATHEUS CARNEIRO AGUIAR',
#  'NORBERTO MELO DE CARVALHO FILHO',
#  'RAIMUNDO NONATO DA SILVA SA SOBRINHO',
#  'SAMARA FEITOSA DE SOUSA',
#  'TIAGO GABRIEL COSTA SAMPAIO',
#  'VICTOR KAUAN DA SILVA MIRANDA',
#  'WELTER XIMENES CANTANHEDE FILHO']

# %%
dicionario_alunos = {}

for matricula, nome in zip(lista_alunos_matriculados, lista_nomes_alunos_limpos):
  print(f"Matrícula: {matricula}, Nome: {nome}")
  dicionario_alunos[matricula] = nome
# Out:
# Matrícula: 20249023385, Nome: ANTONIO CARLOS DE SOUSA COELHO DAMASCENO
# Matrícula: 20249021433, Nome: ANTONIO INACIO DA SILVA NETO
# Matrícula: 20249012229, Nome: ARTHUR MAGNO RODRIGUES SAMPAIO
# Matrícula: 20249021818, Nome: CAUA MARTINS DA SILVA
# Matrícula: 20239035515, Nome: DAVI SOARES DE MACEDO
# Matrícula: 20249022000, Nome: DAVI SOUSA SOARES
# Matrícula: 20249018456, Nome: DIEGO VINICIOS MASCARENHA LIMA
# Matrícula: 20249021264, Nome: DIELSON DE MENDONCA SANTOS
# Matrícula: 20249020884, Nome: FELIPE GABRIEL SOARES RODRIGUES
# Matrícula: 20249022010, Nome: GABRIEL ARAUJO ROCHA
# Matrícula: 20229052844, Nome: HELON SANDES BARROS
# Matrícula: 20249013226, Nome: ITALO MARLON DE SOUSA ALVES
# Matrícula: 20249011704, Nome: JARDENIA MILLENA DE SOUSA ROSA
# Matrícula: 20239057110, Nome: JOAO GABRIEL MIRANDA QUEIROZ
# Matrícula: 20249023278, Nome: JOAO MANOEL COSTA MENEZES
# Matrícula: 20249021961, Nome: JOAO MARCELO BARROS CARDOSO VENTURA
# Matrícula: 20249012194, Nome: JOAO PEDRO SALEH DE SOUSA
# Matrícula: 20249021970, Nome: KAUAN FRANCISCO SANTOS SARAIVA
# Matrícula: 20249020857, Nome: LUANDERSON DAVI GONCALVES TORRES
# Matrícula: 20249012050, Nome: LUANDERSON OLIVEIRA DE CARVALHO
# Matrícula: 20249011769, Nome: LUCAS VILARINHO CARVALHO MARTINS CAMARCO
# Matrícula: 20249021139, Nome: MARCOS VINICIUS DUARTE SOUSA
# Matrícula: 20239049987, Nome: MARIA EDUARDA FARIAS GOMES
# Matrícula: 20239052276, Nome: MATEUS RODRIGUES DE SOUSA BORJA
# Matrícula: 20249012336, Nome: MATHEUS CARNEIRO AGUIAR
# Matrícula: 20219042129, Nome: NORBERTO MELO DE CARVALHO FILHO
# Matrícula: 20249021765, Nome: RAIMUNDO NONATO DA SILVA SA SOBRINHO
# Matrícula: 20249011553, Nome: SAMARA FEITOSA DE SOUSA
# Matrícula: 20239046116, Nome: TIAGO GABRIEL COSTA SAMPAIO
# Matrícula: 20249021999, Nome: VICTOR KAUAN DA SILVA MIRANDA
# Matrícula: 20249023170, Nome: WELTER XIMENES CANTANHEDE FILHO

# %% [markdown]
# # Resolução das listas

# %%
# !wget https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lista1_20242.txt
# !wget https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lista2_20242.txt
# !wget https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lista3_20242.txt
# !wget https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lista4_20242.txt
# Out:
# --2024-10-22 11:18:11--  https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lista1_20242.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 860 [text/plain]
# Saving to: ‘alunos_lista1_20242.txt’
#
# alunos_lista1_20242 100%[===================>]     860  --.-KB/s    in 0s
#
# 2024-10-22 11:18:11 (46.7 MB/s) - ‘alunos_lista1_20242.txt’ saved [860/860]
#
# --2024-10-22 11:18:11--  https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lista2_20242.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 902 [text/plain]
# Saving to: ‘alunos_lista2_20242.txt’
#
# alunos_lista2_20242 100%[===================>]     902  --.-KB/s    in 0s
#
# 2024-10-22 11:18:11 (42.1 MB/s) - ‘alunos_lista2_20242.txt’ saved [902/902]
#
# --2024-10-22 11:18:11--  https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lista3_20242.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 749 [text/plain]
# Saving to: ‘alunos_lista3_20242.txt’
#
# alunos_lista3_20242 100%[===================>]     749  --.-KB/s    in 0s
#
# 2024-10-22 11:18:11 (36.8 MB/s) - ‘alunos_lista3_20242.txt’ saved [749/749]
#
# --2024-10-22 11:18:11--  https://raw.githubusercontent.com/armandossrecife/teste/refs/heads/main/alunos_lista4_20242.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 687 [text/plain]
# Saving to: ‘alunos_lista4_20242.txt’
#
# alunos_lista4_20242 100%[===================>]     687  --.-KB/s    in 0s
#
# 2024-10-22 11:18:12 (25.6 MB/s) - ‘alunos_lista4_20242.txt’ saved [687/687]

# %%
def gera_lista_respostas(arquivo):
  with open(arquivo) as f_lista:
    lista_alunos = f_lista.read().splitlines()
  return lista_alunos

# %%
def gera_dicionario_alunos_lista(dicionario_alunos, lista_alunos_lista):
  dicionario_alunos_lista = {}

  for matricula, nome in dicionario_alunos.items():
    if nome in lista_alunos_lista:
      dicionario_alunos_lista[matricula] = nome

  return dicionario_alunos_lista

def checa_alunos_fezeram_lista(df_alunos, lista_alunos_lista):
  lista1_respostas = []
  for each in lista_alunos_lista:
    if each in df_alunos.nome.tolist():
      print(f"Aluno {each} fez a lista")
      lista1_respostas.append(1)
    else:
      print(f"Aluno {each} não fez a lista")
      lista1_respostas.append(0)

# %%
lista_alunos_lista1_20242= gera_lista_respostas('alunos_lista1_20242.txt')
lista_alunos_lista2_20242 = gera_lista_respostas('alunos_lista2_20242.txt')
lista_alunos_lista3_20242 = gera_lista_respostas('alunos_lista3_20242.txt')
lista_alunos_lista4_20242 = gera_lista_respostas('alunos_lista4_20242.txt')

# %%
print(len(lista_alunos_lista1_20242))
print(len(lista_alunos_lista2_20242))
print(len(lista_alunos_lista3_20242))
print(len(lista_alunos_lista4_20242))
# Out:
# 30
# 31
# 26
# 24

# %%
dicionario_lista1 = gera_dicionario_alunos_lista(dicionario_alunos, lista_alunos_lista1_20242)
dicionario_lista2 = gera_dicionario_alunos_lista(dicionario_alunos, lista_alunos_lista2_20242)
dicionario_lista3 = gera_dicionario_alunos_lista(dicionario_alunos, lista_alunos_lista3_20242)
dicionario_lista4 = gera_dicionario_alunos_lista(dicionario_alunos, lista_alunos_lista4_20242)

# %%
dicionario_lista1
# Out:
# {20249021433: 'ANTONIO INACIO DA SILVA NETO',
#  20249012229: 'ARTHUR MAGNO RODRIGUES SAMPAIO',
#  20249021818: 'CAUA MARTINS DA SILVA',
#  20239035515: 'DAVI SOARES DE MACEDO',
#  20249022000: 'DAVI SOUSA SOARES',
#  20249018456: 'DIEGO VINICIOS MASCARENHA LIMA',
#  20249021264: 'DIELSON DE MENDONCA SANTOS',
#  20249020884: 'FELIPE GABRIEL SOARES RODRIGUES',
#  20249022010: 'GABRIEL ARAUJO ROCHA',
#  20229052844: 'HELON SANDES BARROS',
#  20249013226: 'ITALO MARLON DE SOUSA ALVES',
#  20249011704: 'JARDENIA MILLENA DE SOUSA ROSA',
#  20239057110: 'JOAO GABRIEL MIRANDA QUEIROZ',
#  20249023278: 'JOAO MANOEL COSTA MENEZES',
#  20249021961: 'JOAO MARCELO BARROS CARDOSO VENTURA',
#  20249012194: 'JOAO PEDRO SALEH DE SOUSA',
#  20249021970: 'KAUAN FRANCISCO SANTOS SARAIVA',
#  20249020857: 'LUANDERSON DAVI GONCALVES TORRES',
#  20249012050: 'LUANDERSON OLIVEIRA DE CARVALHO',
#  20249011769: 'LUCAS VILARINHO CARVALHO MARTINS CAMARCO',
#  20249021139: 'MARCOS VINICIUS DUARTE SOUSA',
#  20239049987: 'MARIA EDUARDA FARIAS GOMES',
#  20239052276: 'MATEUS RODRIGUES DE SOUSA BORJA',
#  20249012336: 'MATHEUS CARNEIRO AGUIAR',
#  20219042129: 'NORBERTO MELO DE CARVALHO FILHO',
#  20249021765: 'RAIMUNDO NONATO DA SILVA SA SOBRINHO',
#  20249011553: 'SAMARA FEITOSA DE SOUSA',
#  20239046116: 'TIAGO GABRIEL COSTA SAMPAIO',
#  20249021999: 'VICTOR KAUAN DA SILVA MIRANDA',
#  20249023170: 'WELTER XIMENES CANTANHEDE FILHO'}

# %%
def converte_dicionario_para_dataframe(dicionario):
  df = pd.DataFrame(list(dicionario.items()), columns=['matricula', 'nome'])
  return df

# %%
df_alunos_x = converte_dicionario_para_dataframe(dicionario_alunos)
df_lista1 = converte_dicionario_para_dataframe(dicionario_lista1)
df_lista2 = converte_dicionario_para_dataframe(dicionario_lista2)
df_lista3 = converte_dicionario_para_dataframe(dicionario_lista3)
df_lista4 = converte_dicionario_para_dataframe(dicionario_lista4)

# %%
df_alunos_x
# Out:
#       matricula                                      nome
# 0   20249023385  ANTONIO CARLOS DE SOUSA COELHO DAMASCENO
# 1   20249021433              ANTONIO INACIO DA SILVA NETO
# 2   20249012229            ARTHUR MAGNO RODRIGUES SAMPAIO
# 3   20249021818                     CAUA MARTINS DA SILVA
# 4   20239035515                     DAVI SOARES DE MACEDO
# 5   20249022000                         DAVI SOUSA SOARES
# 6   20249018456            DIEGO VINICIOS MASCARENHA LIMA
# 7   20249021264                DIELSON DE MENDONCA SANTOS
# 8   20249020884           FELIPE GABRIEL SOARES RODRIGUES
# 9   20249022010                      GABRIEL ARAUJO ROCHA
# 10  20229052844                       HELON SANDES BARROS
# 11  20249013226               ITALO MARLON DE SOUSA ALVES
# 12  20249011704            JARDENIA MILLENA DE SOUSA ROSA
# 13  20239057110              JOAO GABRIEL MIRANDA QUEIROZ
# 14  20249023278                 JOAO MANOEL COSTA MENEZES
# 15  20249021961       JOAO MARCELO BARROS CARDOSO VENTURA
# 16  20249012194                 JOAO PEDRO SALEH DE SOUSA
# 17  20249021970            KAUAN FRANCISCO SANTOS SARAIVA
# 18  20249020857          LUANDERSON DAVI GONCALVES TORRES
# 19  20249012050           LUANDERSON OLIVEIRA DE CARVALHO
# 20  20249011769  LUCAS VILARINHO CARVALHO MARTINS CAMARCO
# 21  20249021139              MARCOS VINICIUS DUARTE SOUSA
# 22  20239049987                MARIA EDUARDA FARIAS GOMES
# 23  20239052276           MATEUS RODRIGUES DE SOUSA BORJA
# 24  20249012336                   MATHEUS CARNEIRO AGUIAR
# 25  20219042129           NORBERTO MELO DE CARVALHO FILHO
# 26  20249021765      RAIMUNDO NONATO DA SILVA SA SOBRINHO
# 27  20249011553                   SAMARA FEITOSA DE SOUSA
# 28  20239046116               TIAGO GABRIEL COSTA SAMPAIO
# 29  20249021999             VICTOR KAUAN DA SILVA MIRANDA
# 30  20249023170           WELTER XIMENES CANTANHEDE FILHO

# %% [markdown]
# # Checa os alunos que fizeram as listas

# %%
len(df_alunos_x.nome.tolist())
# Out:
# 31

# %%
def checa_alunos_fezeram_lista(df_alunos, lista_alunos_lista):
  lista1_respostas = []
  for each in df_alunos.nome.tolist():
    if each in lista_alunos_lista:
      print(f"Aluno {each} fez a lista")
      lista1_respostas.append(1)
    else:
      print(f"Aluno {each} não fez a lista")
      lista1_respostas.append(0)
  return lista1_respostas

# %%
lista1_respostas = checa_alunos_fezeram_lista(df_alunos_x, lista_alunos_lista1_20242)
lista2_respostas = checa_alunos_fezeram_lista(df_alunos_x, lista_alunos_lista2_20242)
lista3_respostas = checa_alunos_fezeram_lista(df_alunos_x, lista_alunos_lista3_20242)
lista4_respostas = checa_alunos_fezeram_lista(df_alunos_x, lista_alunos_lista4_20242)
# Out:
# Aluno ANTONIO CARLOS DE SOUSA COELHO DAMASCENO não fez a lista
# Aluno ANTONIO INACIO DA SILVA NETO fez a lista
# Aluno ARTHUR MAGNO RODRIGUES SAMPAIO fez a lista
# Aluno CAUA MARTINS DA SILVA fez a lista
# Aluno DAVI SOARES DE MACEDO fez a lista
# Aluno DAVI SOUSA SOARES fez a lista
# Aluno DIEGO VINICIOS MASCARENHA LIMA fez a lista
# Aluno DIELSON DE MENDONCA SANTOS fez a lista
# Aluno FELIPE GABRIEL SOARES RODRIGUES fez a lista
# Aluno GABRIEL ARAUJO ROCHA fez a lista
# Aluno HELON SANDES BARROS fez a lista
# Aluno ITALO MARLON DE SOUSA ALVES fez a lista
# Aluno JARDENIA MILLENA DE SOUSA ROSA fez a lista
# Aluno JOAO GABRIEL MIRANDA QUEIROZ fez a lista
# Aluno JOAO MANOEL COSTA MENEZES fez a lista
# Aluno JOAO MARCELO BARROS CARDOSO VENTURA fez a lista
# Aluno JOAO PEDRO SALEH DE SOUSA fez a lista
# Aluno KAUAN FRANCISCO SANTOS SARAIVA fez a lista
# Aluno LUANDERSON DAVI GONCALVES TORRES fez a lista
# Aluno LUANDERSON OLIVEIRA DE CARVALHO fez a lista
# Aluno LUCAS VILARINHO CARVALHO MARTINS CAMARCO fez a lista
# Aluno MARCOS VINICIUS DUARTE SOUSA fez a lista
# Aluno MARIA EDUARDA FARIAS GOMES fez a lista
# Aluno MATEUS RODRIGUES DE SOUSA BORJA fez a lista
# Aluno MATHEUS CARNEIRO AGUIAR fez a lista
# Aluno NORBERTO MELO DE CARVALHO FILHO fez a lista
# Aluno RAIMUNDO NONATO DA SILVA SA SOBRINHO fez a lista
# Aluno SAMARA FEITOSA DE SOUSA fez a lista
# Aluno TIAGO GABRIEL COSTA SAMPAIO fez a lista
# Aluno VICTOR KAUAN DA SILVA MIRANDA fez a lista
# Aluno WELTER XIMENES CANTANHEDE FILHO fez a lista
# Aluno ANTONIO CARLOS DE SOUSA COELHO DAMASCENO fez a lista
# Aluno ANTONIO INACIO DA SILVA NETO fez a lista
# Aluno ARTHUR MAGNO RODRIGUES SAMPAIO fez a lista
# Aluno CAUA MARTINS DA SILVA fez a lista
# Aluno DAVI SOARES DE MACEDO fez a lista
# Aluno DAVI SOUSA SOARES fez a lista
# Aluno DIEGO VINICIOS MASCARENHA LIMA fez a lista
# Aluno DIELSON DE MENDONCA SANTOS fez a lista
# Aluno FELIPE GABRIEL SOARES RODRIGUES fez a lista
# Aluno GABRIEL ARAUJO ROCHA fez a lista
# Aluno HELON SANDES BARROS fez a lista
# Aluno ITALO MARLON DE SOUSA ALVES fez a lista
# Aluno JARDENIA MILLENA DE SOUSA ROSA fez a lista
# Aluno JOAO GABRIEL MIRANDA QUEIROZ fez a lista
# Aluno JOAO MANOEL COSTA MENEZES fez a lista
# Aluno JOAO MARCELO BARROS CARDOSO VENTURA fez a lista
# Aluno JOAO PEDRO SALEH DE SOUSA fez a lista
# Aluno KAUAN FRANCISCO SANTOS SARAIVA fez a lista
# Aluno LUANDERSON DAVI GONCALVES TORRES fez a lista
# Aluno LUANDERSON OLIVEIRA DE CARVALHO fez a lista
# Aluno LUCAS VILARINHO CARVALHO MARTINS CAMARCO fez a lista
# Aluno MARCOS VINICIUS DUARTE SOUSA fez a lista
# Aluno MARIA EDUARDA FARIAS GOMES fez a lista
# Aluno MATEUS RODRIGUES DE SOUSA BORJA fez a lista
# Aluno MATHEUS CARNEIRO AGUIAR fez a lista
# Aluno NORBERTO MELO DE CARVALHO FILHO fez a lista
# Aluno RAIMUNDO NONATO DA SILVA SA SOBRINHO fez a lista
# Aluno SAMARA FEITOSA DE SOUSA fez a lista
# Aluno TIAGO GABRIEL COSTA SAMPAIO fez a lista
# Aluno VICTOR KAUAN DA SILVA MIRANDA fez a lista
# Aluno WELTER XIMENES CANTANHEDE FILHO não fez a lista
# Aluno ANTONIO CARLOS DE SOUSA COELHO DAMASCENO fez a lista
# Aluno ANTONIO INACIO DA SILVA NETO fez a lista
# Aluno ARTHUR MAGNO RODRIGUES SAMPAIO fez a lista
# Aluno CAUA MARTINS DA SILVA fez a lista
# Aluno DAVI SOARES DE MACEDO fez a lista
# Aluno DAVI SOUSA SOARES fez a lista
# Aluno DIEGO VINICIOS MASCARENHA LIMA fez a lista
# Aluno DIELSON DE MENDONCA SANTOS fez a lista
# Aluno FELIPE GABRIEL SOARES RODRIGUES fez a lista
# Aluno GABRIEL ARAUJO ROCHA fez a lista
# Aluno HELON SANDES BARROS fez a lista
# Aluno ITALO MARLON DE SOUSA ALVES fez a lista
# Aluno JARDENIA MILLENA DE SOUSA ROSA fez a lista
# Aluno JOAO GABRIEL MIRANDA QUEIROZ não fez a lista
# Aluno JOAO MANOEL COSTA MENEZES fez a lista
# Aluno JOAO MARCELO BARROS CARDOSO VENTURA fez a lista
# Aluno JOAO PEDRO SALEH DE SOUSA fez a lista
# Aluno KAUAN FRANCISCO SANTOS SARAIVA não fez a lista
# Aluno LUANDERSON DAVI GONCALVES TORRES fez a lista
# Aluno LUANDERSON OLIVEIRA DE CARVALHO fez a lista
# Aluno LUCAS VILARINHO CARVALHO MARTINS CAMARCO fez a lista
# Aluno MARCOS VINICIUS DUARTE SOUSA fez a lista
# Aluno MARIA EDUARDA FARIAS GOMES não fez a lista
# Aluno MATEUS RODRIGUES DE SOUSA BORJA fez a lista
# Aluno MATHEUS CARNEIRO AGUIAR fez a lista
# Aluno NORBERTO MELO DE CARVALHO FILHO fez a lista
# Aluno RAIMUNDO NONATO DA SILVA SA SOBRINHO não fez a lista
# Aluno SAMARA FEITOSA DE SOUSA fez a lista
# Aluno TIAGO GABRIEL COSTA SAMPAIO não fez a lista
# Aluno VICTOR KAUAN DA SILVA MIRANDA fez a lista
# Aluno WELTER XIMENES CANTANHEDE FILHO fez a lista
# Aluno ANTONIO CARLOS DE SOUSA COELHO DAMASCENO fez a lista
# Aluno ANTONIO INACIO DA SILVA NETO fez a lista
# Aluno ARTHUR MAGNO RODRIGUES SAMPAIO fez a lista
# Aluno CAUA MARTINS DA SILVA fez a lista
# Aluno DAVI SOARES DE MACEDO fez a lista
# Aluno DAVI SOUSA SOARES fez a lista
# Aluno DIEGO VINICIOS MASCARENHA LIMA fez a lista
# Aluno DIELSON DE MENDONCA SANTOS fez a lista
# Aluno FELIPE GABRIEL SOARES RODRIGUES fez a lista
# Aluno GABRIEL ARAUJO ROCHA fez a lista
# Aluno HELON SANDES BARROS fez a lista
# Aluno ITALO MARLON DE SOUSA ALVES fez a lista
# Aluno JARDENIA MILLENA DE SOUSA ROSA não fez a lista
# Aluno JOAO GABRIEL MIRANDA QUEIROZ fez a lista
# Aluno JOAO MANOEL COSTA MENEZES não fez a lista
# Aluno JOAO MARCELO BARROS CARDOSO VENTURA fez a lista
# Aluno JOAO PEDRO SALEH DE SOUSA fez a lista
# Aluno KAUAN FRANCISCO SANTOS SARAIVA não fez a lista
# Aluno LUANDERSON DAVI GONCALVES TORRES fez a lista
# Aluno LUANDERSON OLIVEIRA DE CARVALHO fez a lista
# Aluno LUCAS VILARINHO CARVALHO MARTINS CAMARCO fez a lista
# Aluno MARCOS VINICIUS DUARTE SOUSA não fez a lista
# Aluno MARIA EDUARDA FARIAS GOMES fez a lista
# Aluno MATEUS RODRIGUES DE SOUSA BORJA fez a lista
# Aluno MATHEUS CARNEIRO AGUIAR fez a lista
# Aluno NORBERTO MELO DE CARVALHO FILHO fez a lista
# Aluno RAIMUNDO NONATO DA SILVA SA SOBRINHO não fez a lista
# Aluno SAMARA FEITOSA DE SOUSA fez a lista
# Aluno TIAGO GABRIEL COSTA SAMPAIO não fez a lista
# Aluno VICTOR KAUAN DA SILVA MIRANDA fez a lista
# Aluno WELTER XIMENES CANTANHEDE FILHO não fez a lista

# %%
len(lista1_respostas)
# Out:
# 31

# %%
df_alunos_respostas = df_alunos_x.copy()
df_alunos_respostas['lista1'] = lista1_respostas
df_alunos_respostas['lista2'] = lista2_respostas
df_alunos_respostas['lista3'] = lista3_respostas
df_alunos_respostas['lista4'] = lista4_respostas

# %%
df_alunos_respostas
# Out:
#       matricula                                      nome  lista1  lista2  \
# 0   20249023385  ANTONIO CARLOS DE SOUSA COELHO DAMASCENO       0       1
# 1   20249021433              ANTONIO INACIO DA SILVA NETO       1       1
# 2   20249012229            ARTHUR MAGNO RODRIGUES SAMPAIO       1       1
# 3   20249021818                     CAUA MARTINS DA SILVA       1       1
# 4   20239035515                     DAVI SOARES DE MACEDO       1       1
# 5   20249022000                         DAVI SOUSA SOARES       1       1
# 6   20249018456            DIEGO VINICIOS MASCARENHA LIMA       1       1
# 7   20249021264                DIELSON DE MENDONCA SANTOS       1       1
# 8   20249020884           FELIPE GABRIEL SOARES RODRIGUES       1       1
# 9   20249022010                      GABRIEL ARAUJO ROCHA       1       1
# 10  20229052844                       HELON SANDES BARROS       1       1
# 11  20249013226               ITALO MARLON DE SOUSA ALVES       1       1
# 12  20249011704            JARDENIA MILLENA DE SOUSA ROSA       1       1
# 13  20239057110              JOAO GABRIEL MIRANDA QUEIROZ       1       1
# 14  20249023278                 JOAO MANOEL COSTA MENEZES       1       1
# 15  20249021961       JOAO MARCELO BARROS CARDOSO VENTURA       1       1
# 16  20249012194                 JOAO PEDRO SALEH DE SOUSA       1       1
# 17  20249021970            KAUAN FRANCISCO SANTOS SARAIVA       1       1
# 18  20249020857          LUANDERSON DAVI GONCALVES TORRES       1       1
# 19  20249012050           LUANDERSON OLIVEIRA DE CARVALHO       1       1
# 20  20249011769  LUCAS VILARINHO CARVALHO MARTINS CAMARCO       1       1
# 21  20249021139              MARCOS VINICIUS DUARTE SOUSA       1       1
# 22  20239049987                MARIA EDUARDA FARIAS GOMES       1       1
# 23  20239052276           MATEUS RODRIGUES DE SOUSA BORJA       1       1
# 24  20249012336                   MATHEUS CARNEIRO AGUIAR       1       1
# 25  20219042129           NORBERTO MELO DE CARVALHO FILHO       1       1
# 26  20249021765      RAIMUNDO NONATO DA SILVA SA SOBRINHO       1       1
# 27  20249011553                   SAMARA FEITOSA DE SOUSA       1       1
# 28  20239046116               TIAGO GABRIEL COSTA SAMPAIO       1       1
# 29  20249021999             VICTOR KAUAN DA SILVA MIRANDA       1       1
# 30  20249023170           WELTER XIMENES CANTANHEDE FILHO       1       0
#
#     lista3  lista4
# 0        1       1
# 1        1       1
# 2        1       1
# 3        1       1
# 4        1       1
# 5        1       1
# 6        1       1
# 7        1       1
# 8        1       1
# 9        1       1
# 10       1       1
# 11       1       1
# 12       1       0
# 13       0       1
# 14       1       0
# 15       1       1
# 16       1       1
# 17       0       0
# 18       1       1
# 19       1       1
# 20       1       1
# 21       1       0
# 22       0       1
# 23       1       1
# 24       1       1
# 25       1       1
# 26       0       0
# 27       1       1
# 28       0       0
# 29       1       1
# 30       1       0
