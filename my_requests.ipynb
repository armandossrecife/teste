# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/teste/blob/main/my_requests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
# https://www.google.com/search?q="Armando Soares Sousa"

termo_consulta = "Armando Soares Sousa"

URL_CONSULTA = f"https://www.google.com/search?q={termo_consulta}"

print(URL_CONSULTA)

minha_consulta = requests.get(URL_CONSULTA)
minha_consulta.raise_for_status()
if minha_consulta.status_code==200:
  conteudo = minha_consulta.content
  # Decode the bytes to a string using UTF-8 encoding (or another appropriate encoding if known)
  conteudo_str = conteudo.decode('latin-1')
  print(conteudo_str)
# Out:
# https://www.google.com/search?q=Armando Soares Sousa
# <!doctype html><html lang="en"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Armando Soares Sousa - Google Search</title><script nonce="tyZuP0Rd3gcYZPSIATwiJw">(function(){
# ...

# %%
# prompt: how to convert bytes to string?

import requests
# https://www.google.com/search?q="Armando Soares Sousa"

termo_consulta = "Armando Soares Sousa"

URL_CONSULTA = f"https://www.google.com/search?q={termo_consulta}"

print(URL_CONSULTA)

minha_consulta = requests.get(URL_CONSULTA)
minha_consulta.raise_for_status()
if minha_consulta.status_code==200:
  conteudo = minha_consulta.content
  print(type(conteudo))

  # Decode the bytes to a string using UTF-8 encoding (or another appropriate encoding if known)
  conteudo_str = conteudo.decode('utf-8')
  print(type(conteudo_str))
conteudo_str
